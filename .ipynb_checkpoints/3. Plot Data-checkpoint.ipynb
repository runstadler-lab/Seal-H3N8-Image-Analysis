# %%
import pandas as pd
from math import sqrt

# %%
lung_data = pd.read_csv('Red-Green Overlap lung.csv', index_col=0)
# Exclude Neg_lung_111313_4.png because it is an outliner.
lung_data = lung_data.drop(6, in_place=True)
lung_data
# Out:
#                      Filename  Red-Green Overlap Sample or Control Tissue  \
# 0      HH3_lung_111313_11.png              23626               HH3   lung
# 7      HH3_lung_111313_11.png              30781               HH3   lung
# 1      HH3_lung_111313_12.png              41035               HH3   lung
# 8      HH3_lung_111313_12.png              54504               HH3   lung
# 2      HH3_lung_111313_13.png              31948               HH3   lung
# 9      HH3_lung_111313_13.png              44801               HH3   lung
# 3       HH3_lung_111313_2.png              11079               HH3   lung
# 10      HH3_lung_111313_2.png              21982               HH3   lung
# 4       HH3_lung_111313_4.png              49023               HH3   lung
# 11      HH3_lung_111313_4.png              57126               HH3   lung
# 5       HH3_lung_111313_5.png              48535               HH3   lung
# 12      HH3_lung_111313_5.png              57580               HH3   lung
# 13      Neg_lung_111313_4.png                  0               Neg   lung
# 14      Neg_lung_111313_5.png                  0               Neg   lung
# 15      Neg_lung_111313_6.png                  0               Neg   lung
# 16  SH3_20_lung_111313_13.png             133937               SH3   lung
# 17  SH3_20_lung_111313_14.png             125912               SH3   lung
# 18  SH3_20_lung_111313_15.png             119032               SH3   lung
# 19  SH3_20_lung_111313_26.png              66606               SH3   lung
# 20  SH3_20_lung_111313_27.png              67782               SH3   lung
# 21  SH3_20_lung_111313_28.png              88757               SH3   lung
# 22  SH3_20_lung_111313_29.png             101488               SH3   lung
# 23  SH3_20_lung_111313_30.png              83763               SH3   lung
#
#         human  Unnamed: 6   Unnamed: 7
# 0       39335         NaN          NaN
# 7         NaN         NaN          NaN
# 1         NaN         NaN          NaN
# 8         NaN         NaN          NaN
# 2         NaN         NaN          NaN
# 9         NaN         NaN          NaN
# 3         NaN         NaN          NaN
# 10        NaN         NaN          NaN
# 4         NaN         NaN          NaN
# 11        NaN         NaN          NaN
# 5         NaN         NaN          NaN
# 12        NaN         NaN          NaN
# 13        NaN         NaN          NaN
# 14        NaN         NaN          NaN
# 15       seal         NaN   human/seal
# 16  98409.625         NaN  0.399706838
# 17        NaN         NaN          NaN
# 18        NaN         NaN          NaN
# 19        NaN         NaN          NaN
# 20        NaN         NaN          NaN
# 21        NaN         NaN          NaN
# 22        NaN         NaN          NaN
# 23        NaN         NaN          NaN

# %%
# Get the average of lung data
lung_data_averaged = lung_data.groupby('Sample or Control').mean()
lung_data_averaged
# Out:
#                    Red-Green Overlap  Unnamed: 6
# Sample or Control
# HH3                            39335         NaN
# Neg                                0         NaN
# SH3                            98409         NaN

# %%
# Get the standard deviation of lung data
lung_data_stdev = lung_data.groupby('Sample or Control').std()
lung_data_stdev
# Out:
#                    Red-Green Overlap  Unnamed: 6
# Sample or Control
# HH3                     15269.703450         NaN
# Neg                         0.000000         NaN
# SH3                     25941.011429         NaN

# %%
# Compute standard error of mean
lung_data_sem = lung_data.groupby('Sample or Control').std()/sqrt(len(lung_data.groupby('Sample or Control')))
lung_data_sem
# Out:
#                    Red-Green Overlap  Unnamed: 6
# Sample or Control
# HH3                      9976.206254         NaN
# Neg                         0.000000         NaN
# SH3                     16948.127467         NaN

# %%
# Combine the data together
lung = pd.DataFrame()
lung['mean'] = lung_data_averaged['Red-Green Overlap']
lung['sem'] = lung_data_sem['Red-Green Overlap']
lung
# Out:
#                     mean           sem
# Sample or Control
# HH3                39335   9976.206254
# Neg                    0      0.000000
# SH3                98409  16948.127467

# %%
trachea_data = pd.read_csv('Red-Green Overlap trachea.csv', index_col=0)
trachea_data
# Out:
#                          Filename  Red-Green Overlap Sample or Control  \
# 0        HH3_trachea_111313_1.png              59375               HH3
# 1        HH3_trachea_111313_3.png              62935               HH3
# 2        HH3_trachea_111313_4.png              54607               HH3
# 3        HH3_trachea_111313_5.png             126582               HH3
# 4        HH3_trachea_111313_6.png             144459               HH3
# 5        HH3_trachea_111313_7.png              54207               HH3
# 6        Neg_trachea_111313_2.png                840               Neg
# 7        Neg_trachea_111313_3.png               2758               Neg
# 8        Neg_trachea_111313_4.png               2546               Neg
# 9        Neg_trachea_111313_5.png                  0               Neg
# 10       Neg_trachea_111313_6.png               3253               Neg
# 11       Neg_trachea_111313_7.png                  0               Neg
# 12       Neg_trachea_111313_8.png                  0               Neg
# 13       Neg_trachea_111313_9.png                117               Neg
# 14   SSH3_40_trachea_111313_1.png              30325              SSH3
# 15  SSH3_40_trachea_111313_13.png               3722              SSH3
# 16  SSH3_40_trachea_111313_14.png                201              SSH3
# 17  SSH3_40_trachea_111313_15.png               3957              SSH3
# 18  SSH3_40_trachea_111313_16.png               4137              SSH3
# 19  SSH3_40_trachea_111313_17.png              22495              SSH3
# 20   SSH3_40_trachea_111313_2.png              22571              SSH3
# 21   SSH3_40_trachea_111313_3.png              20887              SSH3
# 22   SSH3_40_trachea_111313_4.png              13725              SSH3
# 23   SSH3_40_trachea_111313_5.png              11325              SSH3
# 24   SSH3_40_trachea_111313_6.png               8009              SSH3
# 25   SSH3_40_trachea_111313_7.png              10425              SSH3
# 26   SSH3_40_trachea_111313_8.png              11302              SSH3
#
#      Tissue        human  Unnamed: 6   Unnamed: 7
# 0   trachea  83694.16667         NaN          NaN
# 1   trachea          NaN         NaN          NaN
# 2   trachea          NaN         NaN          NaN
# 3   trachea          NaN         NaN          NaN
# 4   trachea          NaN         NaN          NaN
# 5   trachea          NaN         NaN          NaN
# 6   trachea          NaN         NaN          NaN
# 7   trachea          NaN         NaN          NaN
# 8   trachea          NaN         NaN          NaN
# 9   trachea          NaN         NaN          NaN
# 10  trachea          NaN         NaN          NaN
# 11  trachea          NaN         NaN          NaN
# 12  trachea          NaN         NaN          NaN
# 13  trachea         seal         NaN   human/seal
# 14  trachea  12544.69231         NaN  6.671679513
# 15  trachea          NaN         NaN          NaN
# 16  trachea          NaN         NaN          NaN
# 17  trachea          NaN         NaN          NaN
# 18  trachea          NaN         NaN          NaN
# 19  trachea          NaN         NaN          NaN
# 20  trachea          NaN         NaN          NaN
# 21  trachea          NaN         NaN          NaN
# 22  trachea          NaN         NaN          NaN
# 23  trachea          NaN         NaN          NaN
# 24  trachea          NaN         NaN          NaN
# 25  trachea          NaN         NaN          NaN
# 26  trachea          NaN         NaN          NaN

# %%
# Get the average of trachea data
trachea_data_averaged = trachea_data.groupby('Sample or Control').mean()
trachea_data_averaged
# Out:
#                    Red-Green Overlap  Unnamed: 6
# Sample or Control
# HH3                     83694.166667         NaN
# Neg                      1189.250000         NaN
# SSH3                    12544.692308         NaN

# %%
# Compute standard error of mean
trachea_data_sem = trachea_data.groupby('Sample or Control').std()/sqrt(len(trachea_data.groupby('Sample or Control')))
trachea_data_sem
# Out:
#                    Red-Green Overlap  Unnamed: 6
# Sample or Control
# HH3                     26570.115403         NaN
# Neg                       926.439353         NaN
# SSH3                     5932.408043         NaN

# %%
# Combine the data together
trachea = pd.DataFrame()
trachea['mean'] = trachea_data_averaged['Red-Green Overlap']
trachea['sem'] = trachea_data_sem['Red-Green Overlap']
trachea
# Out:
#                            mean           sem
# Sample or Control
# HH3                83694.166667  26570.115403
# Neg                 1189.250000    926.439353
# SSH3               12544.692308   5932.408043

# %%
fig = plt.figure(0)

x = trachea.reset_index().index

barwidth = 0.5

y_lung = lung['mean']
y_err_lung = lung['sem']

y_trachea = trachea['mean']
y_err_trachea = trachea['sem']

plt.bar(left=x, height=y_lung, yerr= y_err_lung, width=barwidth, label="Lung", color='blue', ecolor='black')
plt.bar(left=x+barwidth, height=y_trachea, yerr = y_err_trachea, width=barwidth, label="Trachea", color='red', ecolor='black')

plt.legend()
